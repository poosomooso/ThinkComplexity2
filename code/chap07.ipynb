# %% [markdown]
# # Physical modeling
#
# Code examples from [Think Complexity, 2nd edition](http://greenteapress.com/wp/complexity2), Chapter 7
#
# Copyright 2016 Allen Downey, [MIT License](http://opensource.org/licenses/MIT)

# %%
from __future__ import print_function, division

# %matplotlib inline
# %precision 3

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib.pyplot as plt

import thinkplot

from matplotlib import rc
rc('animation', html='html5')

# %% [markdown]
# ## Diffusion
#
# Before we get to a Reaction-Diffusion model, we'll start with simple diffusion.
#
# The kernel computes the difference between each cell and the sum of its neighbors.
#
# At each time step, we compute this difference, multiply by a constant, and add it back in to the array.

# %%
from Cell2D import Cell2D, Cell2DViewer
from scipy.signal import correlate2d

class Diffusion(Cell2D):
    """Diffusion Cellular Automaton."""

    kernel = np.array([[0, 1, 0],
                       [1,-4, 1],
                       [0, 1, 0]])

    def __init__(self, n, m=None, r=0.1):
        """Initializes the attributes.

        n: number of rows
        m: number of columns
        r: diffusion rate constant
        """
        self.r = r
        m = n if m is None else m
        self.array = np.zeros((n, m), np.float)

    def step(self):
        """Executes one time step."""
        c = correlate2d(self.array, self.kernel, mode='same')
        self.array += self.r * c

# %% [markdown]
# We don't really have to customize the viewer.

# %%
class DiffusionViewer(Cell2DViewer):
    cmap = plt.get_cmap('Reds')

# %% [markdown]
# Here's a simple example starting with an "island" of material in the middle.

# %%
diff = Diffusion(n=9, r=0.1)
diff.add_cells(3, 3, '111', '111', '111')
viewer = DiffusionViewer(diff)

# %% [markdown]
# Here's the initial condition:

# %%
anim = viewer.animate()

# %% [markdown]
# And here's how it behaves over time: the "material" spreads out until the level is equal on the whole array.

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
diff = Diffusion(n=9, r=0.1)
diff.add_cells(3, 3, '111', '111', '111')
viewer = DiffusionViewer(diff)

thinkplot.preplot(cols=3, rows=2)
viewer.draw()

thinkplot.subplot(2)
viewer.step(5)
viewer.draw()

thinkplot.subplot(3)
viewer.step(10)
viewer.draw()

thinkplot.subplot(4)
viewer.step(15)
viewer.draw()

thinkplot.subplot(5)
viewer.step(20)
viewer.draw()

thinkplot.subplot(6)
viewer.step(25)
viewer.draw()

plt.savefig('chap07-1.pdf')

# %% [markdown]
# ## Reaction-Diffusion
#
# Now we'll add a second material and let them interact.
#
# The following function helps with setting up the initial conditions.

# %%
def island(a, val, noise=None):
    """Adds an island in the middle of the array.
            
    val: height of the island
    noise: magnitude of random noise
    """
    noise = val if noise is None else noise
    n, m = a.shape
    island_size = min(n, m) // 20
    island_n = (n//2-island_size, n//2+island_size)
    island_m = (m//2-island_size, m//2+island_size)
    a[island_n[0]:island_n[1], island_m[0]:island_m[1]] = val
    a += noise * np.random.random((n, m))

# %% [markdown]
# For the RD model, we have two arrays, one for each chemical.
#
# Following [Sims](http://www.karlsims.com/rd.html), I'm using a kernel that includes the diagonal elements.  They have lower weights because they are farther from the center cell.
#
# The `step` function computes these functions:
#
# $\Delta A = r_a \nabla^2 A - AB^2 + f (1-A) $
#
# $\Delta B = r_b \nabla^2 B + AB^2 - (k+f) B $
#
# where $\nabla^2$ is the Laplace operator the kernel is intended to approximate.

# %%
class RDParams():
    def __init__(self, rateA=0.5, rateB=0.25, feed=0.035, kill=0.057):
        self.rateA = rateA # diffusion rate for chem A
        self.rateB = rateB # diffusion rate for chem B
        self.feed = feed # the rate at which A is added
        self.kill = kill # the rate at which B is removed

class ReactionDiffusion(Cell2D):
    """Reaction-Diffusion Cellular Automaton."""

    kernel = np.array([[.05, .2, .05],
                       [ .2, -1, .2],
                       [.05, .2, .05]])

    options = dict(mode='same', boundary='wrap')

    def __init__(self, n, m=None, params=None):
        """Initializes the attributes and arrays.
        Begins with chemical 1 everywhere, and an
        island of chemical 2.

        n: number of rows
        m: number of columns
        params: tuple of (Da, Db, f, k)
        """
        
        if params == None:
            self.params = DiffParams()
        else:
            self.params = params
        m = n if m is None else m
        self.array = np.ones((n, m), dtype=float)

        self.array2 = np.zeros((n, m), dtype=float)
        island(self.array2, val=0.1, noise=0.1)
        
    def step(self):
        """Executes one time step."""
        A = self.array
        B = self.array2
        p = self.params
        
        cA = correlate2d(A, self.kernel, **self.options)
        cB = correlate2d(B, self.kernel, **self.options)
        
        reaction = A * B**2 # the rate at which A turns to B
        addedA = p.feed * (1-A)
        removedB = (p.feed+p.kill) * B
        
        self.array += p.rateA * cA - reaction +  addedA
        self.array2 += p.rateB * cB + reaction - removedB

# %% [markdown]
# The viewer for the CA shows both arrays with some transparency, so we can see where one, the other, or both, levels are high.
#
# Unlike previous CAs, the state of each cell is meant to represent a continuous quantity, so it is appropriate to interpolate.
#
# Note that `draw` has to make copies of the arrays because `step` updates the arrays in place.

# %%
class RDViewer(Cell2DViewer):
    """Generates images and animations."""
    
    cmapu = plt.get_cmap('Reds')
    cmapv = plt.get_cmap('Blues')

    options = dict(alpha=0.7,
                  interpolation='bicubic')
        
    def __init__(self, viewee):
        """Initializes the attributes.
        
        viewee: the object to be represented
        """
        self.viewee = viewee
        self.imu = None
        self.imv = None
        self.hlines = None
        self.vlines = None

    def draw(self, grid=False):
        """Draws the cells."""
        au = self.viewee.array.copy()
        av = self.viewee.array2.copy()
        
        n, m = av.shape
        plt.axis([0, m, 0, n])
        plt.xticks([])
        plt.yticks([])

        self.options['extent'] = [0, m, 0, n]
        self.imu = plt.imshow(au, cmap=self.cmapu, **self.options)
        self.imv = plt.imshow(av, cmap=self.cmapv, **self.options)

    def animate_func(self, i):
        """Draws one frame of the animation."""
        if i > 0:
            self.step(iters=100)

        self.imu.set_array(self.viewee.array)
        self.imv.set_array(self.viewee.array2)
        return (self.imu, self.imv)

# %% [markdown]
# Here's an example using `params3`, which yields blue dots that seem to undergo mitosis.

# %%
params1 = RDParams(0.5, 0.25, 0.035, 0.057)   # white spots
params2 = RDParams(0.5, 0.25, 0.055, 0.062)   # coral
params3 = RDParams(0.5, 0.25, 0.039, 0.065)   # blue spots

rd = ReactionDiffusion(100, params=params3)
viewer = RDViewer(rd)

# %% [markdown]
# Here's a random starting condition with lots of A, a sprinkling of B everywhere, and an island of B in the middle.

# %%
anim = viewer.animate(frames=100)

# %% [markdown]
# And here's how it behaves over time.

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# I'll use the following function to generate figures using different parameters.

# %%
def make_viewer(f, k, n=100):
    """Makes a ReactionDiffusion viewer with given parameters.
    """
    params = RDParams(0.5, 0.25, f, k)
    rd = ReactionDiffusion(n, params=params)
    viewer = RDViewer(rd)
    return viewer

# %% [markdown]
# These parameters yield pink stripes and spots on a blue background:

# %%
viewer = make_viewer(0.035, 0.057)

thinkplot.preplot(cols=3)
viewer.step(1000)
viewer.draw()

thinkplot.subplot(2)
viewer.step(2000)
viewer.draw()

thinkplot.subplot(3)
viewer.step(4000)
viewer.draw()

plt.savefig('chap07-2.pdf')

# %% [markdown]
# These parameters yield blue stripes on a pink background.

# %%
viewer = make_viewer(0.055, 0.062)

thinkplot.preplot(cols=3)
viewer.step(1000)
viewer.draw()

thinkplot.subplot(2)
viewer.step(2000)
viewer.draw()

thinkplot.subplot(3)
viewer.step(4000)
viewer.draw()

plt.savefig('chap07-3.pdf')

# %% [markdown]
# These parameters yield pink dots on a blue background

# %%
viewer = make_viewer(0.039, 0.065)

thinkplot.preplot(cols=3)
viewer.step(1000)
viewer.draw()

thinkplot.subplot(2)
viewer.step(2000)
viewer.draw()

thinkplot.subplot(3)
viewer.step(4000)
viewer.draw()

plt.savefig('chap07-4.pdf')

# %% [markdown]
# ## Percolation
#
# In the percolation model, each cell is porous with probability `p`.  We start with a row of wet cells at the time.  During each time step, a cell becomes wet if it is porous and at least one neighbor is wet (using a 4-cell neighborhood).  For each value of `p` we compute the probability that water reaches the bottom row.
#
# Porous cells have state `1` and wet cells have state `5`, so if a cell has a wet neighbor, the sum of the neighbors will by `5` or more.

# %%
from scipy.signal import correlate2d

class Percolation(Cell2D):
    """Percolation Cellular Automaton."""

    kernel = np.array([[0, 1, 0],
                       [1, 0, 1],
                       [0, 1, 0]])

    def __init__(self, n, m=None, p=0.5, seed=None):
        """Initializes the attributes.

        n: number of rows
        m: number of columns
        p: probability of porousness
        """
        self.p = p
        m = n if m is None else m
        if seed is not None:
            np.random.seed(seed)
        self.array = np.random.choice([0, 1], (n, m), p=[1-p, p])
        
        # fill the top row with wet cells
        self.array[0] = 5

    def step(self):
        """Executes one time step."""
        a = self.array
        c = correlate2d(a, self.kernel, mode='same')
        self.array[(a==1) & (c>=5)] = 5
        
    def num_wet(self, cols=None):
        """Total number of wet cells.
        
        cols: number of columns to select
        """
        a = self.array[:, :cols]
        return np.sum(a == 5)
    
    def num_porous(self, cols=None):
        """Total number of porous cells."""
        a = self.array[:, :cols]
        return np.sum(a == 1)
    
    def bottom_row_wet(self):
        """Number of wet cells in the bottom row."""
        return np.sum(self.array[-1] == 5)

# %% [markdown]
# Nothing special about the viewer.

# %%
class PercolationViewer(Cell2DViewer):
    """Draws and animates a Percolation object."""
    cmap = plt.get_cmap('Blues')
    options = dict(alpha=0.6,
                   interpolation='none', 
                   vmin=0, vmax=5)

# %% [markdown]
# Here an example that shows the first three time steps.

# %%
seed = 22
perc = Percolation(10, p=0.5, seed=seed)
viewer = PercolationViewer(perc)

thinkplot.preplot(cols=3)
viewer.step()
viewer.draw()

thinkplot.subplot(2)
viewer.step()
viewer.draw()

thinkplot.subplot(3)
viewer.step()
viewer.draw()

plt.savefig('chap07-5.pdf')

# %% [markdown]
# `test_perc` runs a percolation model and returns `True` if water reaches the bottom row and `False` otherwise.

# %%
def test_perc(perc):
    """Run a percolation model.
    
    Runs until water gets to the bottom row or nothing changes.
    
    returns: (boolean, number of steps)
    """
    num_wet = perc.num_wet()

    num_steps = 0
    while True:
        perc.step()
        num_steps += 1

        if perc.bottom_row_wet():
            return True, num_steps
        
        new_num_wet = perc.num_wet()
        if new_num_wet == num_wet:
            return False, num_steps

        num_wet = new_num_wet

# %% [markdown]
# Run a small example with `p=0.5`

# %%
perc = Percolation(10, p=0.5, seed=seed)
flag, num_steps = test_perc(perc)
print(flag, num_steps)
# Out:
# True 11

# %% [markdown]
# Here's the initial state:

# %%
perc = Percolation(10, p=0.5, seed=seed)
viewer = PercolationViewer(perc)
anim = viewer.animate(frames=num_steps+1)

# %% [markdown]
# And here's the animation

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# For a given `p` we can estimate the probability of a percolating cluster by running several random configurations.

# %%
def estimate_prob_percolating(p=0.5, n=100, iters=100):
    """Estimates the probability of percolating.
    
    p: probability that a cell is permeable
    n: int number of rows and columns
    iters: number of arrays to test
    
    returns: float probability
    """
    count = 0
    for i in range(iters):
        perc = Percolation(n, p=p)
        flag, _ = test_perc(perc)
        if flag:
            count += 1
        
    return count / iters

# %% [markdown]
# At `p=0.55` the probability is low.

# %%
fraction = estimate_prob_percolating(p=0.55)
print(fraction)
# Out:
# 0.01

# %% [markdown]
# At `p=0.6`, the probability is close to 50%, which suggests that the critical value is nearby.

# %%
fraction = estimate_prob_percolating(p=0.6)
print(fraction)
# Out:
# 0.67

# %% [markdown]
# At `p=0.65` the probability is high.

# %%
fraction = estimate_prob_percolating(p=0.65)
print(fraction)
# Out:
# 1.0

# %% [markdown]
# We can search for the critical value by random walk: if there's a percolating cluster, we decrease `p`; otherwise we increase it.
#
# The path should go to the critical point and wander around it.

# %%
def find_critical(p=0.6, n=100, iters=100):
    """Estimate p_crit by random walk.
    
    returns: list of p that should wander around p_crit
    """
    ps = [p]
    for i in range(iters):
        perc = Percolation(n=n, p=p)
        flag, _ = test_perc(perc)
        if flag:
            p -= 0.005
        else:
            p += 0.005
        ps.append(p)
    return ps

# %% [markdown]
# Let's see whether the critical value depends on the size of the grid.
#
# With `n=50`, the random walk wanders around 0.59.

# %%
# %time ps = find_critical(n=50, iters=1000)
thinkplot.plot(ps)
np.mean(ps)
# Out:
# CPU times: user 9.03 s, sys: 0 ns, total: 9.03 s
# Wall time: 9.03 s
# 0.591

# %% [markdown]
# Larger values of `n` don't seem to change the critical value.

# %%
# %time ps = find_critical(n=100, iters=200)
thinkplot.plot(ps)
np.mean(ps)
# Out:
# CPU times: user 12 s, sys: 0 ns, total: 12 s
# Wall time: 12 s
# 0.593

# %%
# %time ps = find_critical(n=200, iters=40)
thinkplot.plot(ps)
np.mean(ps)
# Out:
# CPU times: user 19.7 s, sys: 4 ms, total: 19.8 s
# Wall time: 19.8 s
# 0.592

# %%
# %time ps = find_critical(n=400, iters=10)
thinkplot.plot(ps)
np.mean(ps)
# Out:
# CPU times: user 39.4 s, sys: 8 ms, total: 39.4 s
# Wall time: 39.4 s
# 0.591

# %% [markdown]
# ## Fractals

# %% [markdown]
# Near the critical point, the cluster of wet cells forms a fractal.  We can see that visually in these examples:

# %%
seed = 22
perc1 = Percolation(100, p=0.6, seed=seed)
flag, num_steps = test_perc(perc1)
print(flag, num_steps)
viewer = PercolationViewer(perc1)
viewer.draw()
# Out:
# True 138

# %%
seed = 22
perc2 = Percolation(200, p=0.6, seed=seed)
flag, num_steps = test_perc(perc2)
print(flag, num_steps)
viewer2 = PercolationViewer(perc2)
viewer2.draw()
# Out:
# True 390

# %%
perc3 = Percolation(300, p=0.6, seed=seed)
flag, num_steps = test_perc(perc3)
print(flag, num_steps)
viewer3 = PercolationViewer(perc3)
viewer3.draw()
# Out:
# False 467

# %%
thinkplot.preplot(cols=3)
viewer.draw()

thinkplot.subplot(2)
viewer2.draw()

thinkplot.subplot(3)
viewer3.draw()

plt.savefig('chap07-6.pdf')

# %% [markdown]
# To measure fractal dimension, let's start with 1D CAs.

# %%
from Cell1D import Cell1D, Cell1DViewer

def draw_ca(rule, rows=32):
    ca = Cell1D(rule, rows)
    ca.start_single()
    ca.loop(rows-1)
    viewer = Cell1DViewer(ca)
    viewer.draw()

# %% [markdown]
# Here's one rule that seems clearly 1D, one that is clearly 2D, and one that we can't obviously classify.

# %%
thinkplot.preplot(cols=3)
draw_ca(20)

thinkplot.subplot(2)
draw_ca(50)

thinkplot.subplot(3)
draw_ca(18)

plt.savefig('chap07-7.pdf')

# %% [markdown]
# The following function creates a 1D CA and steps through time, counting the number of on cells after each time step.

# %%
def count_cells(rule, rows=500):
    ca = Cell1D(rule, rows)
    ca.start_single() # start with one cell at the top middle
    
    res = []
    for i in range(1, rows):
        cells = np.sum(ca.array)
        res.append((i, i**2, cells))
        ca.step()
        
    return res

# %% [markdown]
# This function plots the results, comparing the rate of cell growth to `size` and `size**2`.
#
# And it uses linregress to estimate the slope of the line on a log-log scale.

# %%
from scipy.stats import linregress

def test_fractal(rule, ylabel=''):
    steps, steps2, cells = test_fractal_no_plot(rule)
    
    for ys in [cells]:
        params = linregress(np.log(steps), np.log(ys))
        print(params[0])

    thinkplot.plot(steps, steps2, label='d=2', linestyle='dashed')
    thinkplot.plot(steps, cells, label='rule=%d' % rule)
    thinkplot.plot(steps, steps, label='d=1', linestyle='dashed')

    thinkplot.config(xscale='log', yscale='log',
                     xlabel='time steps', ylabel=ylabel,
                     xlim=[1, 600], loc='upper left')

    
        
        
def test_fractal_no_plot(rule):
    res = count_cells(rule)
    steps, steps2, cells = zip(*res)
        
    return steps, steps2, cells

def get_regress(rule):
    steps, steps2, cells = test_fractal_no_plot(rule)
    for ys in [cells]:
        params = linregress(np.log(steps), np.log(ys))
        return params[0]

# %% [markdown]
# The linear rule has dimension close to 1.

# %%
test_fractal(20)
# Out:
# 1.0079212646

# %% [markdown]
# The triangular rule has dimension close to 2.

# %%
test_fractal(50)
# Out:
# 1.97128088363

# %% [markdown]
# And the Sierpinski triangle has fractal dimension approximately 1.57

# %%
test_fractal(18)
# Out:
# 1.57392944118

# %%
thinkplot.preplot(num=3, cols=3)
test_fractal(20, ylabel='number of cells')

thinkplot.subplot(2)
thinkplot.preplot(num=3)
test_fractal(50)

thinkplot.subplot(3)
thinkplot.preplot(num=3)
test_fractal(18)

plt.savefig('chap07-8.pdf')
# Out:
# 1.0079212646
# 1.97128088363
# 1.57392944118

# %% [markdown]
# Mathematically, the fractal dimension is supposed to be:

# %%
np.log(3) / np.log(2)
# Out:
# 1.585

# %% [markdown]
# ## Fractals in percolation models
#
# We can measure the fractal dimension of a percolation model by measuring how the number of wet cells scales as we increase the size of a bounding box.

# %% [markdown]
# The following function takes a percolation model that has run to completion.  It computes bounding boxes with sizes from 10 up to `n-1`, positioned in the center of the array.
#
# For each bounding box it counts the number of wet cells.

# %%
from scipy.stats import linregress

def plot_perc_scaling(sizes, p):
    res = []
    
    for size in sizes:
        perc = Percolation(size, p=p)
        flag, _ = test_perc(perc)
        if flag:
            num_filled = perc.num_wet() - size
            res.append((size, size**2, num_filled))
        
    sizes, cells, filled = zip(*res)
    
    thinkplot.plot(sizes, cells, label='d=2')
    thinkplot.plot(sizes, filled, label='filled', style='.')
    thinkplot.plot(sizes, sizes, label='d=1')
    
    thinkplot.config(xlabel='size',
                    ylabel='cell count',
                    xscale='log', xlim=[9, 110], 
                    yscale='log', ylim=[9, 20000],
                    loc='top left')
    
    for ys in [cells, filled, sizes]:
        params = linregress(np.log(sizes), np.log(ys))
        print(params[0])

# %% [markdown]
# If we plot the number of cells versus the size of the box on a log-log scale, the slope is the fractal dimension.
#
# When `p` is near the critical point, the fractal dimension of the wet cells is near 1.85, but it varies from one run to the next.

# %%
sizes = np.arange(10, 101)
plot_perc_scaling(sizes, p=0.59)

plt.savefig('chap07-9.pdf')
# Out:
# 2.0
# 1.83727381586
# 1.0

# %% [markdown]
# **Exercise:** In Chapter 7 we showed that the Rule 18 CA produces a fractal.
# Can you find other rules that produce fractals?  For each one,
# estimate its fractal dimension.
#
# Note: the `Cell1D` object in `Cell1D.py` does not wrap around from the left edge to the right, which creates some artifacts at the boundaries.  You might want to use `Wrap1D`, which is a child class of `Cell1D` that wraps around.  It is also defined in `Cell1D.py`.

# %%
def all_rules_fractal_dim():
    for rule in range(0, 255):
        dim = get_regress(rule)
        print("rule {}: {}".format(rule, dim))

# %%
all_rules_fractal_dim()
# Out:
# rule 0: 0.0
# rule 1: 1.0794755672416492
# rule 2: 1.0
# rule 3: 1.0794866047235405
# rule 4: 1.0
# rule 5: 1.0794866047235405
# rule 6: 1.0079212645952562
# rule 7: 1.0795223522393775
# rule 8: 0.0
# rule 9: 1.066164160752411
# rule 10: 1.0
# rule 11: 1.0795177546230306
# rule 12: 1.0
# rule 13: 1.0795037185512661
# rule 14: 1.0199573114458127
# rule 15: 1.079506183776104
# rule 16: 1.0
# rule 17: 1.0794866047235405
# rule 18: 1.5739294411777087
# rule 19: 1.0795223522393775
# rule 20: 1.0079212645952562
# rule 21: 1.0795223522393775
# rule 22: 1.5799379493725352
# rule 23: 1.0794714285678364
# rule 24: 1.0
# rule 25: 1.0747805834070445
# rule 26: 1.5739294411777087
# rule 27: 1.0795047070951624
# rule 28: 1.9159209178146506
# rule 29: 1.079534836664378
# rule 30: 1.9448302510520268
# rule 31: 1.079508646539409
# rule 32: 0.0
# rule 33: 1.0794755672416492
# rule 34: 1.0
# rule 35: 1.0794866047235405
# rule 36: 1.0
# rule 37: 1.0793750766182506
# rule 38: 1.0079212645952562
# rule 39: 1.0794976311487505
# rule 40: 0.0
# rule 41: 1.0627170905556338
# rule 42: 1.0
# rule 43: 1.0795177546230306
# rule 44: 1.0
# rule 45: 1.078097939777692
# rule 46: 1.0199573114458127
# rule 47: 1.0795017063029084
# rule 48: 1.0
# rule 49: 1.0794866047235405
# rule 50: 1.9712808836268108
# rule 51: 1.0794976311487505
# rule 52: 1.0079212645952562
# rule 53: 1.0794976311487505
# rule 54: 1.9614323300124175
# rule 55: 1.0794714285678364
# rule 56: 1.0
# rule 57: 1.0900051201768113
# rule 58: 1.9712808836268108
# rule 59: 1.0901211689681496
# rule 60: 1.5739294411777087
# rule 61: 1.079585253173672
# rule 62: 1.9743877574167075
# rule 63: 1.079508646539409
# rule 64: 0.0
# rule 65: 1.066164160752411
# rule 66: 1.0
# rule 67: 1.0747805834070445
# rule 68: 1.0
# rule 69: 1.0795037185512661
# rule 70: 1.9159209178146506
# rule 71: 1.079534836664378
# rule 72: 0.0
# rule 73: 1.0319837312052786
# rule 74: 1.0
# rule 75: 1.0816539466977502
# rule 76: 1.0
# rule 77: 1.0795207949363923
# rule 78: 1.8964611522539925
# rule 79: 1.0795519162685812
# rule 80: 1.0
# rule 81: 1.0795177546230306
# rule 82: 1.5739294411777087
# rule 83: 1.0795047070951624
# rule 84: 1.0199573114458127
# rule 85: 1.079506183776104
# rule 86: 1.9448302510520268
# rule 87: 1.079508646539409
# rule 88: 1.0
# rule 89: 1.0816539466977502
# rule 90: 1.5739294411777087
# rule 91: 1.0797399034683883
# rule 92: 1.8964611522539925
# rule 93: 1.0795519162685812
# rule 94: 1.9339786189940824
# rule 95: 1.0795458149239316
# rule 96: 0.0
# rule 97: 1.0627170905556338
# rule 98: 1.0
# rule 99: 1.0900051201768113
# rule 100: 1.0
# rule 101: 1.078097939777692
# rule 102: 1.5739294411777087
# rule 103: 1.079585253173672
# rule 104: 0.0
# rule 105: 1.053624376187765
# rule 106: 1.0
# rule 107: 1.0955323153979974
# rule 108: 1.0
# rule 109: 1.1151989708355667
# rule 110: 1.925391477705034
# rule 111: 1.0922797481368827
# rule 112: 1.0
# rule 113: 1.0795177546230306
# rule 114: 1.9712808836268108
# rule 115: 1.0901211689681496
# rule 116: 1.0199573114458127
# rule 117: 1.0795017063029084
# rule 118: 1.9743877574167075
# rule 119: 1.079508646539409
# rule 120: 1.0
# rule 121: 1.0955323153979974
# rule 122: 1.9712808836268108
# rule 123: 1.0796653746267069
# rule 124: 1.925391477705034
# rule 125: 1.0922797481368827
# rule 126: 1.5963322585796467
# rule 127: 1.0795458149239316
# rule 128: 0.0
# rule 129: 1.002453337261106
# rule 130: 1.0
# rule 131: 0.9212589402196311
# rule 132: 1.0
# rule 133: 0.9669233297198172
# rule 134: 1.0079212645952562
# rule 135: 0.9670637988991497
# rule 136: 0.0
# rule 137: 1.0157448754386775
# rule 138: 1.0
# rule 139: 1.0558530772135153
# rule 140: 1.0
# rule 141: 1.0292092576421177
# rule 142: 1.0199573114458127
# rule 143: 1.068221483619601
# rule 144: 1.0
# rule 145: 0.9212589402196311
# rule 146: 1.5739294411777087
# rule 147: 0.9674572255275476
# rule 148: 1.0079212645952562
# rule 149: 0.9670637988991497
# rule 150: 1.6919816307815876
# rule 151: 1.0685869181650187
# rule 152: 1.0
# rule 153: 1.0866595702157924
# rule 154: 1.5739294411777087
# rule 155: 1.077229964232547
# rule 156: 1.9159209178146506
# rule 157: 1.0294417744998479
# rule 158: 1.9678645364186171
# rule 159: 1.0773168063488017
# rule 160: 0.0
# rule 161: 1.002453337261106
# rule 162: 1.0
# rule 163: 0.9496081967430979
# rule 164: 1.0
# rule 165: 1.0075799461348989
# rule 166: 1.0079212645952562
# rule 167: 1.0446137133925382
# rule 168: 0.0
# rule 169: 1.0668366715879545
# rule 170: 1.0
# rule 171: 1.0558530772135153
# rule 172: 1.0
# rule 173: 1.0683256446733227
# rule 174: 1.0199573114458127
# rule 175: 1.0683005872443492
# rule 176: 1.0
# rule 177: 0.9496081967430979
# rule 178: 1.9712808836268108
# rule 179: 0.9672751248271277
# rule 180: 1.0079212645952562
# rule 181: 1.0446137133925382
# rule 182: 2.030320395722053
# rule 183: 1.0610251352185003
# rule 184: 1.0
# rule 185: 1.0682707464416825
# rule 186: 1.9712808836268108
# rule 187: 1.0683182654641923
# rule 188: 1.9515560180376352
# rule 189: 1.0802127976014249
# rule 190: 1.982854287981982
# rule 191: 1.0802471487147813
# rule 192: 0.0
# rule 193: 1.0157448754386775
# rule 194: 1.0
# rule 195: 1.0866595702157924
# rule 196: 1.0
# rule 197: 1.0292092576421177
# rule 198: 1.9159209178146506
# rule 199: 1.0294417744998479
# rule 200: 0.0
# rule 201: 1.1026638295005171
# rule 202: 1.0
# rule 203: 1.102702349175024
# rule 204: 1.0
# rule 205: 1.1026597552086335
# rule 206: 1.9712808836268108
# rule 207: 1.102670799500392
# rule 208: 1.0
# rule 209: 1.0558530772135153
# rule 210: 1.5739294411777087
# rule 211: 1.077229964232547
# rule 212: 1.0199573114458127
# rule 213: 1.068221483619601
# rule 214: 1.9678645364186171
# rule 215: 1.0773168063488017
# rule 216: 1.0
# rule 217: 1.102702349175024
# rule 218: 1.5739294411777087
# rule 219: 1.102670799500392
# rule 220: 1.9712808836268108
# rule 221: 1.102670799500392
# rule 222: 2.0
# rule 223: 1.102681832721864
# rule 224: 0.0
# rule 225: 1.0668366715879545
# rule 226: 1.0
# rule 227: 1.0682707464416825
# rule 228: 1.0
# rule 229: 1.0683256446733227
# rule 230: 1.9515560180376352
# rule 231: 1.0802127976014249
# rule 232: 0.0
# rule 233: 1.1028380964448214
# rule 234: 1.0
# rule 235: 1.1027668795404484
# rule 236: 1.0
# rule 237: 1.1027448833383722
# rule 238: 1.9712808836268108
# rule 239: 1.1027133508854776
# rule 240: 1.0
# rule 241: 1.0558530772135153
# rule 242: 1.9712808836268108
# rule 243: 1.0683182654641923
# rule 244: 1.0199573114458127
# rule 245: 1.0683005872443492
# rule 246: 1.982854287981982
# rule 247: 1.0802471487147813
# rule 248: 1.0
# rule 249: 1.1027668795404484
# rule 250: 1.9712808836268108
# rule 251: 1.1027133508854776
# rule 252: 1.9712808836268108
# rule 253: 1.1027133508854776
# rule 254: 2.0

# %%
thinkplot.preplot(cols=3, rows=2)
draw_ca(22)
thinkplot.subplot(2)
draw_ca(26)
thinkplot.subplot(3)
draw_ca(60)
thinkplot.subplot(4)
draw_ca(90)
thinkplot.subplot(5)
draw_ca(102)
thinkplot.subplot(6)
draw_ca(126)

# %%
dim22 = get_regress(22)
print("rule 22: {}".format(dim22))
dim26 = get_regress(26)
print("rule 26: {}".format(dim26))
dim60 = get_regress(60)
print("rule 60: {}".format(dim60))
dim90 = get_regress(90)
print("rule 90: {}".format(dim90))
dim102 = get_regress(102)
print("rule 102: {}".format(dim102))
dim126 = get_regress(126)
print("rule 126: {}".format(dim126))
# Out:
# rule 22: 1.5799379493725352
# rule 26: 1.5739294411777087
# rule 60: 1.5739294411777087
# rule 90: 1.5739294411777087
# rule 102: 1.5739294411777087
# rule 126: 1.5963322585796467

# %% [markdown]
# **Exercise:** In 1990 Bak, Chen and Tang proposed a cellular automaton that is
# an abstract model of a forest fire.  Each cell is in one of three
# states: empty, occupied by a tree, or on fire.
#
# The rules of the CA are:
#
# * An empty cell becomes occupied with probability $p$.
#
# * A cell with a tree burns if any of its neighbors
#   is on fire.
#
# * A cell with a tree spontaneously burns, with
#   probability $f$, even if none of its neighbors is on fire.
#
# * A cell with a burning tree becomes an empty cell in the next
#   time step.
#
# Write a
# program that implements it.  You might want to inherit from `Cell2D`.
# Typical values for the parameters are
# $p=0.01$ and $f=0.001$, but you might want to experiment with other
# values.
#
# Starting from a random initial condition, run the CA until it reaches
# a steady state where the number of trees no longer increases or
# decreases consistently.
#
# In steady state, is the geometry of the forest fractal?
# What is its fractal dimension?

# %%
class ForestFire(Cell2D):
    kernel = np.array([[9, 9, 9],
                       [9, 0, 9],
                       [9, 9, 9]])
    
    def __init__(self, n, p, f):
        self.array = np.zeros((n, n), np.float)
        self.new_tree = p
        self.prob_fire = f

    
    def step(self):
        a = np.array(self.array, copy=True)
        c = correlate2d(a, self.kernel, mode='same')
        random_fire = np.random.random(self.array.shape)
        random_new_tree = np.random.random(self.array.shape)
        
        self.array[(a==9)] = 0
        self.array[(a==1) & ((c>=9) | (random_fire<self.prob_fire))] = 9
        self.array[(a==0) & (random_new_tree < self.new_tree)] = 1
        
    def num_trees(self):
        return np.sum(self.array == 1)
    
    def num_fires(self):
        return np.sum(self.array == 9)

class ForestFireViewer(Cell2DViewer):
    """Draws and animates a Percolation object."""
    cmap = plt.get_cmap('Blues')
    options = dict(alpha=0.6,
                   interpolation='none', 
                   vmin=0, vmax=5)

# %%
forest = ForestFire(50, 0.01, 0.0001)
viewer = ForestFireViewer(forest)
anim = viewer.animate(frames = 200)

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
queue_size = 20
def run_until_stable(forest):
    change_queue = []
    
    def constant_inc_or_dec():
        if len(change_queue) >= queue_size:
            mean_change = np.mean(change_queue)
            return not np.isclose(0, mean_change, atol=0.1)
        return True
    num_steps = 0
    while constant_inc_or_dec():
        num_steps += 1
        start_trees = forest.num_trees()
        forest.step()
        end_trees = forest.num_trees()
        if len(change_queue) >= queue_size:
            change_queue.pop(0)
        change_queue.append(start_trees - end_trees)
        
    return num_steps

# %%
forest = ForestFire(50, 0.001, 0.001)
print(run_until_stable(forest))
viewer = ForestFireViewer(forest)
viewer.draw()
# Out:
# 109

# %%
from scipy.stats import linregress

def plot_forest_scaling(sizes, p, f):
    res = []
    
    for size in sizes:
        forest = ForestFire(size, p, f)
        num_steps = run_until_stable(forest)
        num_trees = forest.num_trees()
        res.append((size, size**2, num_trees))
        
    sizes, cells, filled = zip(*res)
    
    thinkplot.plot(sizes, cells, label='d=2')
    thinkplot.plot(sizes, filled, label='filled', style='.')
    thinkplot.plot(sizes, sizes, label='d=1')
    
    thinkplot.config(xlabel='size',
                    ylabel='cell count',
                    xscale='log', xlim=[9, 110], 
                    yscale='log', ylim=[9, 20000],
                    loc='top left')
    
    for ys in [cells, filled, sizes]:
        params = linregress(np.log(sizes), np.log(ys))
        print(params[0])

# %%
sizes = np.arange(10, 101)
plot_forest_scaling(sizes, 0.001, 0.001)
# Out:
# 2.0
# 2.54336045989
# 1.0

# %%
# Solution goes here

# %%
# Solution goes here

# %%
# Solution goes here
